# %%
import random

import pandas as pd
import numpy as np

df_products = pd.read_csv("../Assets/products-1000.csv", sep=None, engine="python")

# %%
#- creating non repetitive values for the index
new_index = np.arange(0,1000)

# %%
#- shuffling the indexes
random.shuffle(new_index)

# %%
#- create a new column with new index
df_products['new_index'] = new_index
df_products
# Out:
#      Index                                    Name  \
# 0        1                 Thermostat Drone Heater
# 1        2   Ultra Speaker Iron Grill Advanced One
# 2        3                 Watch Headphones Kettle
# 3        4   Portable Toaster Clock Monitor Silent
# 4        5                        Pro Toaster Oven
# ..     ...                                     ...
# 995    996  Silent Router Phone Portable Automatic
# 996    997              Digital Treadmill Clean Go
# 997    998                  Wireless Vacuum Shaver
# 998    999  Portable Cooker Brush 360 Digital Mini
# 999   1000          Smart Watch Edge Digital Sense
#
#                                          Description  \
# 0             Consumer approach woman us those star.
# 1    Point suggest easy money operation could white.
# 2                           Reach husband education.
# 3              Always choose school poor table main.
# 4            Worry put discuss easy back too career.
# ...

# %%
#- set new Index
df_products.set_index('new_index') # update a copy
df_products.set_index('new_index' , inplace=True) # make the original one update

# %%
#- Sort By Index
df_products.sort_index()
# Out:
#            Index                                             Name  \
# new_index
# 0            373      Advanced Powerbank Scooter Rechargeable Air
# 1            395                   Wireless Radio Smart Air Prime
# 2            497                             Compact Router Smart
# 3            286  Mini Mouse Monitor Phone Plus Wireless Wireless
# 4            946                      Clean Grill Grill Mini Mini
# ...          ...                                              ...
# 995          251         Eco Brush Blender Vacuum Automatic Ultra
# 996          951              Rechargeable Projector Air 360 Lite
# 997           20                                     Cooker Brush
# 998           62                         Advanced Toaster Scanner
# 999          264                         Rechargeable Phone Grill
#
#                                                  Description  \
# new_index
# 0            Brother should method contain strategy similar.
# ...
