# %%
#------------------------Page Five----------------------------
import pandas as pd
import numpy as np

# %%
#-----------------------Joins----------------------------#
#-------Inner Join------
# Merge
df1 = pd.DataFrame({'id':['A','B','C','D'],
                    'age':[21,22,23,24]})
df2 = pd.DataFrame({'id':['C','D','E','F'],
                    'job':['Doctor','Accountant','Developer','Teacher']})

# %%
print(df1)
print(df2)
# Out:
#   id  age
# 0  A   21
# 1  B   22
# 2  C   23
# 3  D   24
#   id         job
# 0  C      Doctor
# 1  D  Accountant
# 2  E   Developer
# 3  F     Teacher

# %%
# Inner Join - Example one
df_inner_join = df1.merge(df2, on='id',how='inner')

print(df_inner_join)
# Out:
#   id  age         job
# 0  C   23      Doctor
# 1  D   24  Accountant

# %%
# shape
print(df1.shape)
print(df2.shape)
print(df_inner_join.shape)
# Out:
# (4, 2)
# (4, 2)
# (2, 3)

# %%
df_movies = pd.read_csv('../Assets/IMDb movies.csv')
df_ratings = pd.read_csv('../Assets/IMDb ratings.csv')

# %%
df_movies = df_movies[['imdb_title_id', 'title', 'year', 'genre', 'country']]
df_ratings = df_ratings[['imdb_title_id', 'total_votes', 'mean_vote']]

# %%
# Example Two
df_movies_inner = df_movies.merge(df_ratings, on='imdb_title_id', how='inner')

# %%
print(df_movies_inner.shape)
print(df_ratings.shape)
print(df_movies.shape)
# Out:
# (80424, 7)
# (85855, 3)
# (81273, 5)

# %%
df_movies_inner
# Out:
#       imdb_title_id                                              title  year  \
# 0         tt0000574                        The Story of the Kelly Gang  1906
# 1         tt0001892                                     Den sorte drøm  1911
# 2         tt0002101                                          Cleopatra  1912
# 3         tt0002130                                          L'Inferno  1911
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...  1912
# ...             ...                                                ...   ...
# 80419     tt9903716                                             Jessie  2019
# 80420     tt9905412                                              Ottam  2019
# 80421     tt9905462                                          Pengalila  2019
# 80422     tt9911774                          Padmavyuhathile Abhimanyu  2019
# 80423     tt9914286                                  Sokagin Çocuklari  2019
#
#                            genre           country  total_votes  mean_vote
# 0        Biography, Crime, Drama         Australia          589        6.3
# 1                          Drama  Germany, Denmark          188        6.0
# 2                 Drama, History               USA          446        5.3
# 3      Adventure, Drama, Fantasy             Italy         2237        6.9
# 4               Biography, Drama               USA          484        5.8
# ...                          ...               ...          ...        ...
# 80419           Horror, Thriller             India          318        7.7
# 80420                      Drama             India          494        7.9
# 80421                      Drama             India          553        8.5
# 80422                      Drama             India          265        7.8
# 80423              Drama, Family            Turkey          194        9.4
#
# [80424 rows x 7 columns]

# %%
# Inner join with pd.merge
pd.merge(df_movies_inner, df_movies, on='imdb_title_id', how='inner')
# Out:
#       imdb_title_id                                            title_x  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                     Den sorte drøm
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 80419     tt9903716                                             Jessie
# 80420     tt9905412                                              Ottam
# 80421     tt9905462                                          Pengalila
# 80422     tt9911774                          Padmavyuhathile Abhimanyu
# 80423     tt9914286                                  Sokagin Çocuklari
#
#        year_x                    genre_x         country_x  total_votes  \
# 0        1906    Biography, Crime, Drama         Australia          589
# 1        1911                      Drama  Germany, Denmark          188
# 2        1912             Drama, History               USA          446
# 3        1911  Adventure, Drama, Fantasy             Italy         2237
# 4        1912           Biography, Drama               USA          484
# ...       ...                        ...               ...          ...
# 80419    2019           Horror, Thriller             India          318
# 80420    2019                      Drama             India          494
# 80421    2019                      Drama             India          553
# 80422    2019                      Drama             India          265
# 80423    2019              Drama, Family            Turkey          194
#
#        mean_vote                                            title_y  year_y  \
# 0            6.3                        The Story of the Kelly Gang    1906
# 1            6.0                                     Den sorte drøm    1911
# 2            5.3                                          Cleopatra    1912
# 3            6.9                                          L'Inferno    1911
# 4            5.8  From the Manger to the Cross; or, Jesus of Naz...    1912
# ...          ...                                                ...     ...
# 80419        7.7                                             Jessie    2019
# 80420        7.9                                              Ottam    2019
# 80421        8.5                                          Pengalila    2019
# 80422        7.8                          Padmavyuhathile Abhimanyu    2019
# 80423        9.4                                  Sokagin Çocuklari    2019
#
#                          genre_y         country_y
# 0        Biography, Crime, Drama         Australia
# 1                          Drama  Germany, Denmark
# 2                 Drama, History               USA
# 3      Adventure, Drama, Fantasy             Italy
# 4               Biography, Drama               USA
# ...                          ...               ...
# 80419           Horror, Thriller             India
# 80420                      Drama             India
# 80421                      Drama             India
# 80422                      Drama             India
# 80423              Drama, Family            Turkey
#
# [80424 rows x 11 columns]

# %%
#----------------------Full Join-----------------------------------
df1.merge(df2,on='id',how='outer')
# Out:
#   id   age         job
# 0  A  21.0         NaN
# 1  B  22.0         NaN
# 2  C  23.0      Doctor
# 3  D  24.0  Accountant
# 4  E   NaN   Developer
# 5  F   NaN     Teacher

# %%
df_movies_outer = df_movies.merge(df_ratings,on='imdb_title_id',how='outer')

# %%
print(df_movies.shape)
print(df_ratings.shape)
print(df_movies_outer.shape)
# Out:
# (81273, 5)
# (85855, 3)
# (86704, 7)

# %%
pd.merge(df_movies,df_ratings,on='imdb_title_id',how='outer')
# Out:
#       imdb_title_id                        title    year  \
# 0         tt0000009                          NaN     NaN
# 1         tt0000574  The Story of the Kelly Gang  1906.0
# 2         tt0001892               Den sorte drøm  1911.0
# 3         tt0002101                    Cleopatra  1912.0
# 4         tt0002130                    L'Inferno  1911.0
# ...             ...                          ...     ...
# 86699     tt9908390                          NaN     NaN
# 86700     tt9911196                          NaN     NaN
# 86701     tt9911774    Padmavyuhathile Abhimanyu  2019.0
# 86702     tt9914286            Sokagin Çocuklari  2019.0
# 86703     tt9914942                          NaN     NaN
#
#                            genre           country  total_votes  mean_vote
# 0                            NaN               NaN        154.0        5.9
# 1        Biography, Crime, Drama         Australia        589.0        6.3
# 2                          Drama  Germany, Denmark        188.0        6.0
# 3                 Drama, History               USA        446.0        5.3
# 4      Adventure, Drama, Fantasy             Italy       2237.0        6.9
# ...                          ...               ...          ...        ...
# 86699                        NaN               NaN        398.0        5.5
# 86700                        NaN               NaN        724.0        7.9
# 86701                      Drama             India        265.0        7.8
# 86702              Drama, Family            Turkey        194.0        9.4
# 86703                        NaN               NaN        102.0        6.8
#
# [86704 rows x 7 columns]

# %%
#-------------Exclusive Full join(show result opposite to inner join)-------------------
df1.merge(df2,on='id',how='outer',indicator=True)
# Out:
#   id   age         job      _merge
# 0  A  21.0         NaN   left_only
# 1  B  22.0         NaN   left_only
# 2  C  23.0      Doctor        both
# 3  D  24.0  Accountant        both
# 4  E   NaN   Developer  right_only
# 5  F   NaN     Teacher  right_only

# %%
# query - select left only and right only values
df1.merge(df2,on='id',how='outer',indicator=True).query("_merge=='left_only' or _merge=='right_only'")
# Out:
#   id   age        job      _merge
# 0  A  21.0        NaN   left_only
# 1  B  22.0        NaN   left_only
# 4  E   NaN  Developer  right_only
# 5  F   NaN    Teacher  right_only

# %%
df_movies_exclusive = df_movies.merge(df_ratings,on='imdb_title_id',how='outer',indicator=True)

# %%
df_movies_exclusive
# Out:
#       imdb_title_id                        title    year  \
# 0         tt0000009                          NaN     NaN
# 1         tt0000574  The Story of the Kelly Gang  1906.0
# 2         tt0001892               Den sorte drøm  1911.0
# 3         tt0002101                    Cleopatra  1912.0
# 4         tt0002130                    L'Inferno  1911.0
# ...             ...                          ...     ...
# 86699     tt9908390                          NaN     NaN
# 86700     tt9911196                          NaN     NaN
# 86701     tt9911774    Padmavyuhathile Abhimanyu  2019.0
# 86702     tt9914286            Sokagin Çocuklari  2019.0
# 86703     tt9914942                          NaN     NaN
#
#                            genre           country  total_votes  mean_vote  \
# 0                            NaN               NaN        154.0        5.9
# 1        Biography, Crime, Drama         Australia        589.0        6.3
# 2                          Drama  Germany, Denmark        188.0        6.0
# 3                 Drama, History               USA        446.0        5.3
# 4      Adventure, Drama, Fantasy             Italy       2237.0        6.9
# ...                          ...               ...          ...        ...
# 86699                        NaN               NaN        398.0        5.5
# 86700                        NaN               NaN        724.0        7.9
# 86701                      Drama             India        265.0        7.8
# 86702              Drama, Family            Turkey        194.0        9.4
# 86703                        NaN               NaN        102.0        6.8
#
#            _merge
# 0      right_only
# 1            both
# 2            both
# 3            both
# 4            both
# ...           ...
# 86699  right_only
# 86700  right_only
# 86701        both
# 86702        both
# 86703  right_only
#
# [86704 rows x 8 columns]

# %%
pd.merge(df_movies,df_ratings,on='imdb_title_id',how='outer',indicator=True).query("_merge=='left_only' or _merge=='right_only'")
# Out:
#       imdb_title_id              title    year         genre country  \
# 0         tt0000009                NaN     NaN           NaN     NaN
# 14        tt0003102                NaN     NaN           NaN     NaN
# 28        tt0003952  Le faux magistrat  1914.0  Crime, Drama  France
# 42        tt0004743                NaN     NaN           NaN     NaN
# 56        tt0005680                NaN     NaN           NaN     NaN
# ...             ...                ...     ...           ...     ...
# 86695     tt9904802                NaN     NaN           NaN     NaN
# 86698     tt9906644                NaN     NaN           NaN     NaN
# 86699     tt9908390                NaN     NaN           NaN     NaN
# 86700     tt9911196                NaN     NaN           NaN     NaN
# 86703     tt9914942                NaN     NaN           NaN     NaN
#
#        total_votes  mean_vote      _merge
# 0            154.0        5.9  right_only
# 14           100.0        6.3  right_only
# 28             NaN        NaN   left_only
# 42           112.0        5.4  right_only
# 56           130.0        5.9  right_only
# ...            ...        ...         ...
# 86695        764.0        6.4  right_only
# 86698        491.0        7.2  right_only
# 86699        398.0        5.5  right_only
# 86700        724.0        7.9  right_only
# 86703        102.0        6.8  right_only
#
# [6280 rows x 8 columns]
