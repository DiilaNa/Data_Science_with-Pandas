# %%
#!pip install plotly
#!pip install cufflinks

# %%
import cufflinks as cf
from IPython.display import display,HTML

cf.set_config_file(sharing='public',theme='ggplot',offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %%
import pandas as pd
import plotly.express as px

# %%
df_population_raw = pd.read_csv("../Assets/population.csv")

# %%
df_population_raw.dropna(inplace=True)

# %%
df_pivot = df_population_raw.pivot(index='Year', columns='Country Name', values='Value')

# %%
df_pivot = df_pivot[['United States','India','China','Indonesia','Brazil']]

# %%
df_pivot
# Out:
# Country Name  United States         India         China    Indonesia  \
# Year
# 1960            180671000.0  4.359903e+08  6.670700e+08   88296070.0
# 1961            183691000.0  4.465647e+08  6.603300e+08   90791249.0
# 1962            186538000.0  4.572831e+08  6.657700e+08   93375850.0
# 1963            189242000.0  4.681386e+08  6.823350e+08   96051424.0
# 1964            191889000.0  4.792296e+08  6.983550e+08   98833749.0
# ...                     ...           ...           ...          ...
# 2019            328329953.0  1.389030e+09  1.407745e+09  272489381.0
# 2020            331526933.0  1.402618e+09  1.411100e+09  274814866.0
# 2021            332048977.0  1.414204e+09  1.412360e+09  276758053.0
# 2022            333271411.0  1.425423e+09  1.412175e+09  278830529.0
# 2023            334914895.0  1.438070e+09  1.410710e+09  281190067.0
#
# Country Name       Brazil
# Year
# 1960           72388126.0
# 1961           74605447.0
# 1962           76865323.0
# ...

# %%
df_pivot.iplot(kind = 'bar')
# works only in notebook as i am using pycharm i need to use above codes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_pivot.iplot(kind = 'bar')
#       2 # works only in notebook as i am using pycharm i need to use above codes
#
# NameError: name 'df_pivot' is not defined

# %%
# interactive Line chart
fig = px.line(df_pivot, x=df_pivot.index, y=df_pivot.columns)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# interactive barplot

df_pivot_2020=df_pivot[df_pivot.index.isin([2020])]

# %%
df_pivot_2020 = df_pivot_2020.T

# %%
df_pivot_2020
# Out:
# Year                   2020
# Country Name
# United States  3.315269e+08
# India          1.402618e+09
# China          1.411100e+09
# Indonesia      2.748149e+08
# Brazil         2.086608e+08

# %%
fig = px.bar(df_pivot_2020, x=df_pivot_2020.index, y=df_pivot_2020.columns,title='Population by Country',color_discrete_sequence=px.colors.sequential.Darkmint)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Interactive barplot grouped by 'n' variables
df_pivot_sample = df_pivot[df_pivot.index.isin([1970,1980,1990,2000,2010,2020])]

# %%
df_pivot_sample
# Out:
# Country Name  United States         India         China    Indonesia  \
# Year
# 1970            205052000.0  5.458643e+08  8.183150e+08  115657495.0
# 1980            227225000.0  6.873540e+08  9.812350e+08  148950540.0
# 1990            249623000.0  8.649722e+08  1.135185e+09  183501098.0
# 2000            282162411.0  1.057923e+09  1.262645e+09  216077790.0
# 2010            309327143.0  1.243482e+09  1.337705e+09  246305322.0
# 2020            331526933.0  1.402618e+09  1.411100e+09  274814866.0
#
# Country Name       Brazil
# Year
# 1970           95375651.0
# 1980          121207461.0
# 1990          149143223.0
# 2000          174018282.0
# 2010          193701929.0
# 2020          208660842.0

# %%
fig = px.bar(df_pivot_sample, x=df_pivot_sample.index, y=df_pivot_sample.columns,title='Population[1970-2020]')
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#-Interactive Pie chart

df_pivot_2020.rename(columns={2020:'2020'},inplace=True)

# %%
df_pivot_2020 = df_pivot_2020.reset_index()

# %%
fig = px.pie(df_pivot_2020, values='2020',names='Country Name',title='2020')
fig.update_traces(textinfo='percent', textposition='inside')
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Boxplot
import plotly.express as px

fig = px.box(y=df_pivot['United States'], title='United States', labels={'y': 'Values', 'x': 'United States'})
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df_pivot, title='Population by Country', labels={'value': 'Population', 'variable': 'Country'})
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Interactive Histogram
fig = px.histogram(df_pivot['United States'], title='Population by Country', labels={'value': 'Population'}, nbins=3)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df_pivot[['United States','Indonesia']], title='Population by Country', labels={'value': 'Population'}, nbins=3)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Interactive ScatterPlot
fig = px.scatter(df_pivot)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
