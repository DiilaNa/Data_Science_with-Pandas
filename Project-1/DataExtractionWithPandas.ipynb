# %%
#------------------------Page Three----------------------------
import pandas as pd
import numpy as np
df_players = pd.read_csv("../Assets/fifa_players.csv", engine='python')

# %%
# selecting data with loc() and iloc()

# loc() is label-based so we have to specify rows and columns based in their index/row and column labels

# Value---------df.loc['zero']
# List----------df.loc[['zero','two']]
# Slicing-------df.loc['zero':'two']

#-------------------------------------------------------------------------
# iloc() is integer position-based so we have to specify rows and columns by their integer position values (0-based integer position)

# Value-------- df.iloc[0]
# List----------df.iloc[[0,2]]
# Slicing-------df.iloc[0:2]

# %%
df_players
# Out:
#                  name                         full_name birth_date  age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 2            P. Pogba                        Paul Pogba  3/15/1993   25
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ...               ...                               ...        ...  ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# ...

# %%
# set index
df_players.set_index('name',inplace=True)

# %%
df_players
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
df_players = df_players[['full_name','birth_date','age','height_cm','weight_kgs','nationality','national_team','national_rating'
    ]]

# %%
df_players
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
# selecting with a single value

# get all data about Messi
df_players.loc['L. Messi']
# Out:
# full_name          Lionel Andrés Messi Cuccittini
# birth_date                              6/24/1987
# age                                            31
# height_cm                                  170.18
# weight_kgs                                   72.1
# nationality                             Argentina
# national_team                           Argentina
# national_rating                              82.0
# Name: L. Messi, dtype: object

# %%
df_players.loc['L. Messi','height_cm']
# Out:
# np.float64(170.18)

# %%
# get weight of Cr7
df_players.loc[('Cristiano Ronaldo','weight_kgs')]
# Out:
# np.float64(83.0)

# %%
# get all rows inside the height column
df_players.loc[:,'height_cm']
# Out:
# name
# L. Messi          170.18
# C. Eriksen        154.94
# P. Pogba          190.50
# L. Insigne        162.56
# K. Koulibaly      187.96
#                    ...
# R. McKenzie       175.26
# M. Sipľak         182.88
# J. Bekkema        185.42
# A. Al Yami        175.26
# Júnior Brumado    190.50
# Name: height_cm, Length: 17954, dtype: float64

# %%
# get all columns that correspond to the index 'L.Messi'
df_players.loc['L. Messi',:]
# Out:
# full_name          Lionel Andrés Messi Cuccittini
# birth_date                              6/24/1987
# age                                            31
# height_cm                                  170.18
# weight_kgs                                   72.1
# nationality                             Argentina
# national_team                           Argentina
# national_rating                              82.0
# Name: L. Messi, dtype: object

# %%
# selecting with a list of values

# get all data about messi and ronaldo
df_players.loc[['L. Messi','Cristiano Ronaldo']]
# Out:
#                                              full_name birth_date  age  \
# name
# L. Messi                Lionel Andrés Messi Cuccittini  6/24/1987   31
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   2/5/1985   34
#
#                    height_cm  weight_kgs nationality national_team  \
# name
# L. Messi              170.18        72.1   Argentina     Argentina
# Cristiano Ronaldo     187.96        83.0    Portugal      Portugal
#
#                    national_rating
# name
# L. Messi                      82.0
# Cristiano Ronaldo             82.0

# %%
# get the height of messi and ronaldo
df_players.loc[['L. Messi','Cristiano Ronaldo'],'height_cm']
# Out:
# name
# L. Messi             170.18
# Cristiano Ronaldo    187.96
# Name: height_cm, dtype: float64

# %%
# get height and weight of messi
df_players.loc['L. Messi',['height_cm','weight_kgs']]
# Out:
# height_cm     170.18
# weight_kgs      72.1
# Name: L. Messi, dtype: object

# %%
# get height and weight of messi and ronaldo
df_players.loc[['L. Messi','Cristiano Ronaldo'],['height_cm','weight_kgs']]
# Out:
#                    height_cm  weight_kgs
# name
# L. Messi              170.18        72.1
# Cristiano Ronaldo     187.96        83.0

# %%
# ------------------Selecting a range of data with a slice -------

# slice column labels
players = ['L. Messi','Cristiano Ronaldo']

df_players.loc[players, 'age':'national_team']
# Out:
#                    age  height_cm  weight_kgs nationality national_team
# name
# L. Messi            31     170.18        72.1   Argentina     Argentina
# Cristiano Ronaldo   34     187.96        83.0    Portugal      Portugal

# %%
# slice index labels
columns = ['age','height_cm','weight_kgs']

df_players.index[:10]
df_players.loc['L. Messi':'E. Cavani',columns]
# Out:
#               age  height_cm  weight_kgs
# name
# L. Messi       31     170.18        72.1
# C. Eriksen     27     154.94        76.2
# P. Pogba       25     190.50        83.9
# L. Insigne     27     162.56        59.0
# K. Koulibaly   27     187.96        88.9
# V. van Dijk    27     193.04        92.1
# K. Mbappé      20     152.40        73.0
# S. Agüero      30     172.72        69.9
# M. Neuer       32     193.04        92.1
# E. Cavani      32     185.42        77.1

# %%
# ------------------------- Selecting with conditions--------------
# select player with height above 180cm
columns = ['age','height_cm','weight_kgs']
df_players.loc[df_players['height_cm'] > 180,columns]
# Out:
#                    age  height_cm  weight_kgs
# name
# P. Pogba            25     190.50        83.9
# K. Koulibaly        27     187.96        88.9
# V. van Dijk         27     193.04        92.1
# M. Neuer            32     193.04        92.1
# E. Cavani           32     185.42        77.1
# ...                ...        ...         ...
# Cristiano Ronaldo   34     187.96        83.0
# J. Serra            20     193.04        87.1
# M. Sipľak           23     182.88        79.8
# J. Bekkema          22     185.42        89.8
# Júnior Brumado      19     190.50        79.8
#
# [8900 rows x 3 columns]

# %%
#------------Selecting players with multiple conditions----------------------

(df_players['height_cm']>180) & (df_players['nationality']=="Argentina")

df_players.loc[(df_players['height_cm']>180) & (df_players['national_team']=="Argentina"),:
]
# Out:
#                                full_name birth_date  age  height_cm  \
# name
# R. Funes Mori     José Ramiro Funes Mori   3/5/1991   28     185.42
# S. Romero           Sergio Germán Romero  2/22/1987   32     193.04
# R. Pereyra               Roberto Pereyra   1/7/1991   28     182.88
# G. Pezzella    Germán Alejandro Pezzella  6/27/1991   27     185.42
# E. Lamela                    Erik Lamela   3/4/1992   27     182.88
# N. Otamendi      Nicolás Hernán Otamendi  2/12/1988   31     182.88
#
#                weight_kgs nationality national_team  national_rating
# name
# R. Funes Mori        78.9   Argentina     Argentina             82.0
# S. Romero            87.1   Argentina     Argentina             82.0
# R. Pereyra           77.1   Argentina     Argentina             82.0
# G. Pezzella          81.2   Argentina     Argentina             82.0
# E. Lamela            79.8   Argentina     Argentina             82.0
# ...

# %%
df_players
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
#---------------------iloc()-------------------------------------
#--Select Single Values
# Get the Birthdate of the messi
df_players.iloc[0,1]
# Out:
# '6/24/1987'

# %%
# Get the weight of Paul Pogba
df_players.iloc[2,4]
# Out:
# np.float64(83.9)

# %%
# get all rows inside the height column
df_players.iloc[:,3]
# Out:
# name
# L. Messi          170.18
# C. Eriksen        154.94
# P. Pogba          190.50
# L. Insigne        162.56
# K. Koulibaly      187.96
#                    ...
# R. McKenzie       175.26
# M. Sipľak         182.88
# J. Bekkema        185.42
# A. Al Yami        175.26
# Júnior Brumado    190.50
# Name: height_cm, Length: 17954, dtype: float64

# %%
# get all the columns that correspond to the index L. Messi
df_players.iloc[0, :]
# Out:
# full_name          Lionel Andrés Messi Cuccittini
# birth_date                              6/24/1987
# age                                            31
# height_cm                                  170.18
# weight_kgs                                   72.1
# nationality                             Argentina
# national_team                           Argentina
# national_rating                              82.0
# Name: L. Messi, dtype: object

# %%
#-----------------Selecting with a list of values--------
#get all data about L. Messi and Pogba

df_players.iloc[[0,2]]
# Out:
#                                full_name birth_date  age  height_cm  \
# name
# L. Messi  Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# P. Pogba                      Paul Pogba  3/15/1993   25     190.50
#
#           weight_kgs nationality national_team  national_rating
# name
# L. Messi        72.1   Argentina     Argentina             82.0
# P. Pogba        83.9      France        France             84.0

# %%
# get the height of messi and pogba
df_players.iloc[[0,2],3]
# Out:
# name
# L. Messi    170.18
# P. Pogba    190.50
# Name: height_cm, dtype: float64

# %%
# get the height and weight of pogba and messi
df_players.iloc[[0,2],[3,4]]
# Out:
#           height_cm  weight_kgs
# name
# L. Messi     170.18        72.1
# P. Pogba     190.50        83.9

# %%
#-----------------Selecting a range of data with a slice---------------

# slice column labels age and nationality
players = [0, 1]
df_players.iloc[players,2:6]
# Out:
#             age  height_cm  weight_kgs nationality
# name
# L. Messi     31     170.18        72.1   Argentina
# C. Eriksen   27     154.94        76.2     Denmark

# %%
# get top 10 players in the list
columns = [1,2,3,4]
df_players.iloc[0:10,columns]
# Out:
#               birth_date  age  height_cm  weight_kgs
# name
# L. Messi       6/24/1987   31     170.18        72.1
# C. Eriksen     2/14/1992   27     154.94        76.2
# P. Pogba       3/15/1993   25     190.50        83.9
# L. Insigne      6/4/1991   27     162.56        59.0
# K. Koulibaly   6/20/1991   27     187.96        88.9
# V. van Dijk     7/8/1991   27     193.04        92.1
# K. Mbappé     12/20/1998   20     152.40        73.0
# S. Agüero       6/2/1988   30     172.72        69.9
# M. Neuer       3/27/1986   32     193.04        92.1
# E. Cavani      2/14/1987   32     185.42        77.1

# %%
# ----------------------selecting with conditions-------------------
columns = [1,2,3,4]

df_players.iloc[list(df_players['height_cm']>186),columns]
# Out:
#                   birth_date  age  height_cm  weight_kgs
# name
# P. Pogba           3/15/1993   25     190.50        83.9
# K. Koulibaly       6/20/1991   27     187.96        88.9
# V. van Dijk         7/8/1991   27     193.04        92.1
# M. Neuer           3/27/1986   32     193.04        92.1
# Sergio Busquets    7/16/1988   30     187.96        76.2
# ...                      ...  ...        ...         ...
# H. Kane            7/28/1993   25     187.96        88.9
# De Gea             11/7/1990   28     193.04        76.2
# Cristiano Ronaldo   2/5/1985   34     187.96        83.0
# J. Serra           3/13/1998   20     193.04        87.1
# Júnior Brumado     5/15/1999   19     190.50        79.8
#
# [4153 rows x 4 columns]

# %%
df_players.iloc[list((df_players['height_cm']>180) & (df_players['national_team']=='Argentina')),:]
# Out:
#                                full_name birth_date  age  height_cm  \
# name
# R. Funes Mori     José Ramiro Funes Mori   3/5/1991   28     185.42
# S. Romero           Sergio Germán Romero  2/22/1987   32     193.04
# R. Pereyra               Roberto Pereyra   1/7/1991   28     182.88
# G. Pezzella    Germán Alejandro Pezzella  6/27/1991   27     185.42
# E. Lamela                    Erik Lamela   3/4/1992   27     182.88
# N. Otamendi      Nicolás Hernán Otamendi  2/12/1988   31     182.88
#
#                weight_kgs nationality national_team  national_rating
# name
# R. Funes Mori        78.9   Argentina     Argentina             82.0
# S. Romero            87.1   Argentina     Argentina             82.0
# R. Pereyra           77.1   Argentina     Argentina             82.0
# G. Pezzella          81.2   Argentina     Argentina             82.0
# E. Lamela            79.8   Argentina     Argentina             82.0
# ...

# %%
#------------------------------Set Values to one cell------------------

# update the height of messi
df_players.loc['L. Messi','height_cm'] = 168

# %%
df_players
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31     168.00
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
#----------set a value to entire column-------------------------
df_players.loc[:,'height_cm'] = 190

# %%
df_players
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31      190.0
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27      190.0
# P. Pogba                              Paul Pogba  3/15/1993   25      190.0
# L. Insigne                       Lorenzo Insigne   6/4/1991   27      190.0
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27      190.0
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25      190.0
# M. Sipľak                          Michal Sipľak   2/2/1996   23      190.0
# J. Bekkema                           Jan Bekkema   4/9/1996   22      190.0
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21      190.0
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19      190.0
#
# ...

# %%
#---set values to a entire row
df_players.iloc[-1, :]
# Out:
# full_name          José Francisco dos Santos Júnior
# birth_date                                5/15/1999
# age                                              19
# height_cm                                     190.0
# weight_kgs                                     79.8
# nationality                                  Brazil
# national_team                                   NaN
# national_rating                                 NaN
# Name: Júnior Brumado, dtype: object

# %%
df_players.iloc[-1, :] = np.nan

# %%
df_players.tail(1)
# Out:
#       name full_name birth_date  age  height_cm  weight_kgs positions  \
# 17953  NaN       NaN        NaN  NaN        NaN         NaN       NaN
#
#       nationality  overall_rating  potential  ...  long_shots  aggression  \
# 17953         NaN             NaN        NaN  ...         NaN         NaN
#
#       interceptions  positioning  vision  penalties composure  marking  \
# 17953           NaN          NaN     NaN        NaN       NaN      NaN
#
#       standing_tackle  sliding_tackle
# 17953             NaN             NaN
#
# [1 rows x 51 columns]

# %%
df_players
# Out:
#                name                       full_name birth_date   age  \
# 0          L. Messi  Lionel Andrés Messi Cuccittini  6/24/1987  31.0
# 1        C. Eriksen    Christian  Dannemann Eriksen  2/14/1992  27.0
# 2          P. Pogba                      Paul Pogba  3/15/1993  25.0
# 3        L. Insigne                 Lorenzo Insigne   6/4/1991  27.0
# 4      K. Koulibaly               Kalidou Koulibaly  6/20/1991  27.0
# ...             ...                             ...        ...   ...
# 17949   R. McKenzie                  Rory  McKenzie  10/7/1993  25.0
# 17950     M. Sipľak                   Michal Sipľak   2/2/1996  23.0
# 17951    J. Bekkema                     Jan Bekkema   4/9/1996  22.0
# 17952    A. Al Yami             Abdulrahman Al Yami  6/19/1997  21.0
# 17953           NaN                             NaN        NaN   NaN
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# ...

# %%
#---------------Set value to multiple cells----------------------
df_players.loc[['L. Messi','Cristiano Ronaldo'],'height_cm'] = 175

# %%
columns = ['age','height_cm','weight_kgs']

df_players.loc[df_players['height_cm'] > 180,columns]
# Out:
#                    age  height_cm  weight_kgs
# name
# P. Pogba            25     190.50        83.9
# K. Koulibaly        27     187.96        88.9
# V. van Dijk         27     193.04        92.1
# M. Neuer            32     193.04        92.1
# E. Cavani           32     185.42        77.1
# ...                ...        ...         ...
# Cristiano Ronaldo   34     187.96        83.0
# J. Serra            20     193.04        87.1
# M. Sipľak           23     182.88        79.8
# J. Bekkema          22     185.42        89.8
# Júnior Brumado      19     190.50        79.8
#
# [8900 rows x 3 columns]

# %%
df_players
# Out:
#                  name                         full_name birth_date  age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 2            P. Pogba                        Paul Pogba  3/15/1993   25
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ...               ...                               ...        ...  ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# ...

# %%
#--------------------------Drop Rows in a DATA FRAME ------------------

# drop one row
# 1) aix parameter

# 0 is row and 1 in column
df_players.drop('L. Messi',axis=0)
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# V. van Dijk                      Virgil van Dijk   7/8/1991   27     193.04
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
# 2) index parameter

df_players.drop(index=['L. Messi'])
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# V. van Dijk                      Virgil van Dijk   7/8/1991   27     193.04
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
# drop two or more data
df_players.drop(['C. Eriksen','K. Koulibaly'] ,axis=0)
# Out:
#                                        full_name  birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini   6/24/1987   31     170.18
# P. Pogba                              Paul Pogba   3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne    6/4/1991   27     162.56
# V. van Dijk                      Virgil van Dijk    7/8/1991   27     193.04
# K. Mbappé                          Kylian Mbappé  12/20/1998   20     152.40
# ...                                          ...         ...  ...        ...
# R. McKenzie                       Rory  McKenzie   10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak    2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema    4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami   6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior   5/15/1999   19     190.50
#
# ...

# %%
# --Drop Columns

# axis parameter
df_players.drop('full_name',axis=1)
# Out:
#                birth_date  age  height_cm  weight_kgs   nationality  \
# name
# L. Messi        6/24/1987   31     170.18        72.1     Argentina
# C. Eriksen      2/14/1992   27     154.94        76.2       Denmark
# P. Pogba        3/15/1993   25     190.50        83.9        France
# L. Insigne       6/4/1991   27     162.56        59.0         Italy
# K. Koulibaly    6/20/1991   27     187.96        88.9       Senegal
# ...                   ...  ...        ...         ...           ...
# R. McKenzie     10/7/1993   25     175.26        74.8      Scotland
# M. Sipľak        2/2/1996   23     182.88        79.8      Slovakia
# J. Bekkema       4/9/1996   22     185.42        89.8   Netherlands
# A. Al Yami      6/19/1997   21     175.26        64.9  Saudi Arabia
# Júnior Brumado  5/15/1999   19     190.50        79.8        Brazil
#
#                national_team  national_rating
# name
# L. Messi           Argentina             82.0
# ...

# %%
# column parameter
df_players.drop(columns=['age'])
# Out:
#                                        full_name birth_date  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987     170.18
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992     154.94
# P. Pogba                              Paul Pogba  3/15/1993     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991     187.96
# ...                                          ...        ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999     190.50
#
#                 weight_kgs   nationality national_team  national_rating
# name
# ...

# %%
df_players
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
# drop columns by position - deleting national rating

df_players.drop(df_players.columns[[-1]], axis=1)
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
# drop two or more columns
df_players.drop(['full_name','birth_date'],axis=1)
# Out:
#                 age  height_cm  weight_kgs   nationality national_team  \
# name
# L. Messi         31     170.18        72.1     Argentina     Argentina
# C. Eriksen       27     154.94        76.2       Denmark       Denmark
# P. Pogba         25     190.50        83.9        France        France
# L. Insigne       27     162.56        59.0         Italy         Italy
# K. Koulibaly     27     187.96        88.9       Senegal           NaN
# ...             ...        ...         ...           ...           ...
# R. McKenzie      25     175.26        74.8      Scotland           NaN
# M. Sipľak        23     182.88        79.8      Slovakia           NaN
# J. Bekkema       22     185.42        89.8   Netherlands           NaN
# A. Al Yami       21     175.26        64.9  Saudi Arabia           NaN
# Júnior Brumado   19     190.50        79.8        Brazil           NaN
#
#                 national_rating
# name
# L. Messi                   82.0
# C. Eriksen                 78.0
# ...

# %%
#------------Sample()---------------------
# extract 10 numbers from the nationality column - result is randomly chosen/ with random state 99 chances remains the same set
df_players['nationality'].sample(10,random_state=99)
# Out:
# name
# C. Goldson            England
# Wang Yun             China PR
# B. Berríos              Chile
# M. Calderoni            Italy
# T. Conlon             England
# Juan Pérez              Spain
# D. Chávez              Mexico
# N. Angulo            Colombia
# M. Diallo             Senegal
# S. Caldwell     United States
# Name: nationality, dtype: object

# %%
# extract 20% sample of df
df_players.sample(frac=0.2,random_state=12)
# Out:
#                                  full_name  birth_date  age  height_cm  \
# name
# Antoñito        Antonio Jesús Regal Angulo  12/24/1987   31     175.26
# M. Perrotta                 Marco Perrotta   2/14/1994   25     185.42
# S. Çiftpınar               Sadık Çiftpınar    1/1/1993   26     154.94
# N. Omladič                     Nik Omladič   8/21/1989   29     154.94
# M. Al Rashidi           Mukhair Al Rashidi   5/20/1999   19     170.18
# ...                                    ...         ...  ...        ...
# Yan Hao                                 阎浩    1/9/1999   20     185.42
# A. Miranchuk               Anton Miranchuk  10/17/1995   23     182.88
# S. Dann                         Scott Dann   2/14/1987   32     187.96
# J. Guillemenot          Jérémy Guillemenot    1/6/1998   21     182.88
# Li Fang                                 李放   1/27/1993   26     175.26
#
#                 weight_kgs   nationality national_team  national_rating
# name
# ...

# %%
#---------------------Query()-------------------------------------
# select players older than 34
df_players.query("age>34")
# Out:
#                                         full_name  birth_date  age  height_cm  \
# name
# Z. Ibrahimović                 Zlatan Ibrahimović   10/3/1981   37     195.58
# Juiano Mestres   Juan Everton Mestres de Mesquita   2/29/1984   35     154.94
# Everton Andrão        Everton Jorge Andrade Zanon   2/29/1984   35     152.40
# Joaquín                 Joaquín Sánchez Rodríguez   7/21/1981   37     152.40
# J. Mathieu                         Jérémy Mathieu  10/29/1983   35     187.96
# ...                                           ...         ...  ...        ...
# A. Robben                            Arjen Robben   1/23/1984   35     154.94
# Quaresma        Ricardo Andrade Quaresma Bernardo   9/26/1983   35     175.26
# Naldo                Ronaldo  Aparecido Rodrigues   9/10/1982   36     198.12
# Pepe                 Képler Laveran Lima Ferreira   2/26/1983   36     187.96
# G. Buffon                        Gianluigi Buffon   1/28/1978   41     193.04
#
# ...

# %%
# write boolean slicing
df_players[df_players['age']>34]
# Out:
#                                         full_name  birth_date  age  height_cm  \
# name
# Z. Ibrahimović                 Zlatan Ibrahimović   10/3/1981   37     195.58
# Juiano Mestres   Juan Everton Mestres de Mesquita   2/29/1984   35     154.94
# Everton Andrão        Everton Jorge Andrade Zanon   2/29/1984   35     152.40
# Joaquín                 Joaquín Sánchez Rodríguez   7/21/1981   37     152.40
# J. Mathieu                         Jérémy Mathieu  10/29/1983   35     187.96
# ...                                           ...         ...  ...        ...
# A. Robben                            Arjen Robben   1/23/1984   35     154.94
# Quaresma        Ricardo Andrade Quaresma Bernardo   9/26/1983   35     175.26
# Naldo                Ronaldo  Aparecido Rodrigues   9/10/1982   36     198.12
# Pepe                 Képler Laveran Lima Ferreira   2/26/1983   36     187.96
# G. Buffon                        Gianluigi Buffon   1/28/1978   41     193.04
#
# ...

# %%
# with the query syntax dont use & use and instead
df_players.query("age>34 and nationality=='Italy'")

# write boolean slicing
df_players[(df_players['age']>34) & (df_players['nationality']=='Italy')]
# Out:
#                             full_name  birth_date  age  height_cm  weight_kgs  \
# name
# S. Sorrentino      Stefano Sorrentino   3/28/1979   39     185.42        84.8
# A. Diamanti       Alessandro Diamanti    5/2/1983   35     154.94        74.8
# D. Dainelli            Dario Dainelli    6/9/1979   39     190.50        78.0
# A. Rosina           Alessandro Rosina   1/31/1984   35     170.18        68.9
# S. Pellissier       Sergio Pellissier   4/12/1979   39     175.26        76.2
# A. Rosati              Antonio Rosati   6/26/1983   35     195.58        81.2
# N. Pulzetti             Nico Pulzetti   2/13/1984   35     175.26        69.9
# G. Munari               Gianni Munari   6/24/1983   35     190.50        83.9
# C. Del Grosso    Cristiano Del Grosso   3/24/1983   35     170.18        66.2
# A. Bruno             Alessandro Bruno    7/4/1983   35     154.94        69.9
# P. Gori            Pier Graziano Gori   5/10/1980   38     187.96        83.0
# ...

# %%
#df_players.query("not(age>34)")

df_players[~(df_players['age']>34)]
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# L. Messi          Lionel Andrés Messi Cuccittini  6/24/1987   31     170.18
# C. Eriksen          Christian  Dannemann Eriksen  2/14/1992   27     154.94
# P. Pogba                              Paul Pogba  3/15/1993   25     190.50
# L. Insigne                       Lorenzo Insigne   6/4/1991   27     162.56
# K. Koulibaly                   Kalidou Koulibaly  6/20/1991   27     187.96
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie  10/7/1993   25     175.26
# M. Sipľak                          Michal Sipľak   2/2/1996   23     182.88
# J. Bekkema                           Jan Bekkema   4/9/1996   22     185.42
# A. Al Yami                   Abdulrahman Al Yami  6/19/1997   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19     190.50
#
# ...

# %%
# convert height to Meters and select those with height above 1.8
df_players.query("height_cm/100 > 1.8")
# Out:
#                                              full_name birth_date  age  \
# name
# P. Pogba                                    Paul Pogba  3/15/1993   25
# K. Koulibaly                         Kalidou Koulibaly  6/20/1991   27
# V. van Dijk                            Virgil van Dijk   7/8/1991   27
# M. Neuer                                  Manuel Neuer  3/27/1986   32
# E. Cavani                 Edinson Roberto Cavani Gómez  2/14/1987   32
# ...                                                ...        ...  ...
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   2/5/1985   34
# J. Serra                              Janni-Luca Serra  3/13/1998   20
# M. Sipľak                                Michal Sipľak   2/2/1996   23
# J. Bekkema                                 Jan Bekkema   4/9/1996   22
# Júnior Brumado        José Francisco dos Santos Júnior  5/15/1999   19
#
#                    height_cm  weight_kgs positions  nationality  \
# name
# ...

# %%
# select players who born after 1990
df_players.dtypes
# Out:
# full_name                         object
# birth_date                        object
# age                                int64
# height_cm                        float64
# weight_kgs                       float64
# positions                         object
# nationality                       object
# overall_rating                     int64
# potential                          int64
# value_euro                       float64
# wage_euro                        float64
# preferred_foot                    object
# international_reputation(1-5)      int64
# weak_foot(1-5)                     int64
# skill_moves(1-5)                   int64
# body_type                         object
# release_clause_euro              float64
# national_team                     object
# national_rating                  float64
# national_team_position            object
# national_jersey_number           float64
# crossing                           int64
# finishing                          int64
# ...

# %%
df_players['birth_date'] = df_players['birth_date'].astype('datetime64[ns]')
df_players['birth_date'].dt.year
# Out:
# name
# L. Messi          1987
# C. Eriksen        1992
# P. Pogba          1993
# L. Insigne        1991
# K. Koulibaly      1991
#                   ...
# R. McKenzie       1993
# M. Sipľak         1996
# J. Bekkema        1996
# A. Al Yami        1997
# Júnior Brumado    1999
# Name: birth_date, Length: 17954, dtype: int32

# %%
# convert birth_date column to datetime type
df_players['birth_date'] = df_players['birth_date'].astype('datetime64[ns]')
# Query
df_players.query("birth_date > 1990")
# Out:
#                                        full_name birth_date  age  height_cm  \
# name
# C. Eriksen          Christian  Dannemann Eriksen 1992-02-14   27     154.94
# P. Pogba                              Paul Pogba 1993-03-15   25     190.50
# L. Insigne                       Lorenzo Insigne 1991-06-04   27     162.56
# K. Koulibaly                   Kalidou Koulibaly 1991-06-20   27     187.96
# V. van Dijk                      Virgil van Dijk 1991-07-08   27     193.04
# ...                                          ...        ...  ...        ...
# R. McKenzie                       Rory  McKenzie 1993-10-07   25     175.26
# M. Sipľak                          Michal Sipľak 1996-02-02   23     182.88
# J. Bekkema                           Jan Bekkema 1996-04-09   22     185.42
# A. Al Yami                   Abdulrahman Al Yami 1997-06-19   21     175.26
# Júnior Brumado  José Francisco dos Santos Júnior 1999-05-15   19     190.50
#
# ...
